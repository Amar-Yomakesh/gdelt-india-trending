# %%
import pandas as pd
import extract_gdelt as gdelt

result = []
for theme in gdelt.themes_lookup():
    try:
        print("theme :{i}", theme)
        theme_df = gdelt.extract_gdelt_timeline_bytheme(theme)
        result.append([theme, theme_df['Article Count'].sum(), theme_df['All Articles'].sum()])
    except:
        print("theme invalid, {i}", theme)
      # key = "files/"+datetime.now().strftime("%Y-%m-%d")+"_"+theme+".csv"
      # aws.writeToS3(pd, key)
    if len(result) == 10:
        break
    
df = pd.DataFrame(result)
df.columns=['theme','totalThemedArticles','totalGdeltArticles']
df
# Out:
# theme :{i} EDUCATION
# theme :{i} GENERAL_HEALTH
# theme :{i} TAX_FNCACT
# theme invalid, {i} TAX_FNCACT
# theme :{i} TAX_ETHNICITY
# theme invalid, {i} TAX_ETHNICITY
# theme :{i} EPU_POLICY
# theme invalid, {i} EPU_POLICY
# theme :{i} CRISISLEX_CRISISLEXREC
# theme :{i} TAX_WORLDLANGUAGES
# theme invalid, {i} TAX_WORLDLANGUAGES
# theme :{i} SOC_POINTSOFINTEREST
# theme invalid, {i} SOC_POINTSOFINTEREST
# theme :{i} LEADER
# theme :{i} USPEC_POLITICS_GENERAL1
#                      theme  totalThemedArticles  totalGdeltArticles
# 0                EDUCATION                  677              130217
# 1           GENERAL_HEALTH                  797              130217
# 2   CRISISLEX_CRISISLEXREC                 1220              130217
# 3                   LEADER                  904              130217
# 4  USPEC_POLITICS_GENERAL1                 1409              130217

# %%
#df[['theme','totalThemedArticles']].plot.bar(x='theme',y='totalThemedArticles', rot=500)

article_extract = gdelt.extract_gdelt_articles("USPEC_POLITICS_GENERAL1")

# %%
result = article_extract[article_extract.language == "English"][["url","language","title"]]
result.url[20]
# Out:
# 'https://www.thehindu.com/opinion/op-ed/a-more-conciliatory-approach/article69313691.ece'

# %%
from bs4 import BeautifulSoup
import requests


page = requests.get(result.url[20])
BeautifulSoup(page.content,'html')
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/NewsArticle" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml"><head><title>
# 	A more conciliatory approach - The Hindu
# ...
